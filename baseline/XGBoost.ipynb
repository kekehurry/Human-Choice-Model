# %%
desire = 'Eat'
choice_type = 'mode'
experiment_id = 'xgboost01'

# %%
from models.xgboost import XGBoost

model = XGBoost(data_dir='data')

for num_sample in range(1, 21, 1):
    num_sample = num_sample * 1000
    print(f"experiment_id: {experiment_id}, num_sample: {num_sample}")
    model.run_experiment(experiment_id, num_sample, desire, choice_type)
# Out:
# experiment_id: xgboost01, num_sample: 1000
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': None, 'n_estimators': 100, 'subsample': 0.7}
# loss: 1.0860533413831923
# brier_score: 0.2194184170797576
# mean_error: 0.16362142374680372
#
# experiment_id: xgboost01, num_sample: 2000
# best_params: {'gamma': 0.1, 'learning_rate': 0.001, 'max_depth': None, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.087765109853704
# brier_score: 0.2198174087035747
# mean_error: 0.13719858404901678
#
# experiment_id: xgboost01, num_sample: 3000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0880690832521254
# brier_score: 0.21987807095446615
# mean_error: 0.08117455432390276
#
# experiment_id: xgboost01, num_sample: 4000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0979025726941085
# brier_score: 0.22206310737155505
# mean_error: 0.15259023867211916
#
# experiment_id: xgboost01, num_sample: 5000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0950801222364632
# brier_score: 0.22142431642195054
# mean_error: 0.12473504838228007
#
# experiment_id: xgboost01, num_sample: 6000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0945663964005548
# brier_score: 0.2213088709649491
# mean_error: 0.11462801073435105
#
# experiment_id: xgboost01, num_sample: 7000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': None, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0966416815313202
# brier_score: 0.2217699808174251
# mean_error: 0.18827835059161951
#
# experiment_id: xgboost01, num_sample: 8000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0934183654118566
# brier_score: 0.22104753745607858
# mean_error: 0.12929800262084384
#
# experiment_id: xgboost01, num_sample: 9000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0933863849558096
# brier_score: 0.22103986247737684
# mean_error: 0.1594898187187257
#
# experiment_id: xgboost01, num_sample: 10000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0928219800035515
# brier_score: 0.22091609040651972
# mean_error: 0.1750217010150767
#
# experiment_id: xgboost01, num_sample: 11000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0928820286884684
# brier_score: 0.2209277236253472
# mean_error: 0.18183219017632138
#
# experiment_id: xgboost01, num_sample: 12000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.093078007785091
# brier_score: 0.22097159485519163
# mean_error: 0.172073625360295
#
# experiment_id: xgboost01, num_sample: 13000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0928138662697298
# brier_score: 0.22091415871621986
# mean_error: 0.1992874045870095
#
# experiment_id: xgboost01, num_sample: 14000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0832588878216218
# brier_score: 0.21878421589565158
# mean_error: 0.1599986068633309
#
# experiment_id: xgboost01, num_sample: 15000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0835097310944712
# brier_score: 0.21884002694642776
# mean_error: 0.12902816339802578
#
# experiment_id: xgboost01, num_sample: 16000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.083540637516007
# brier_score: 0.21884650234103892
# mean_error: 0.14740714682536973
#
# experiment_id: xgboost01, num_sample: 17000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0838083002920302
# brier_score: 0.21890851317922225
# mean_error: 0.13143790028591384
#
# experiment_id: xgboost01, num_sample: 18000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 20, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.083971423314085
# brier_score: 0.21894546364309225
# mean_error: 0.12205679766655672
#
# experiment_id: xgboost01, num_sample: 19000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0837231239062155
# brier_score: 0.21888943412767872
# mean_error: 0.15194971503887778
#
# experiment_id: xgboost01, num_sample: 20000
# /Users/kai/anaconda3/envs/pytorch/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# best_params: {'gamma': 0.2, 'learning_rate': 0.001, 'max_depth': 10, 'n_estimators': 100, 'subsample': 0.9}
# loss: 1.0836569861150895
# brier_score: 0.21887366232380295
# mean_error: 0.14295033172523938

# %%
import os
import json
import pandas as pd
import numpy as np


experiment_dir = f'data/experiments/{experiment_id}'
columns = ['experiment_id', 'num_sample', 'desire', 'choice_type', 'loss', 'brier_score', 'age_group_error',
           'income_group_error', 'family_structure_error', 'household_size_error', 'vehicles_error', 'mean_error']
experiment_results = pd.DataFrame(columns=columns)
for file in os.listdir(experiment_dir):
    if file.endswith('.json'):
        with open(os.path.join(experiment_dir, file)) as f:
            experiment_results.loc[len(experiment_results)] = json.load(f)
experiment_results.head()
# Out:
#   experiment_id  num_sample desire choice_type      loss  brier_score  \
# 0     xgboost01        2000    Eat        mode  1.087765     0.219817
# 1     xgboost01       11000    Eat        mode  1.092882     0.220928
# 2     xgboost01       18000    Eat        mode  1.083971     0.218945
# 3     xgboost01       36000    Eat        mode  1.083438     0.218824
# 4     xgboost01       26000    Eat        mode  1.083255     0.218783
#
#    age_group_error  income_group_error  family_structure_error  \
# 0         0.140178            0.156565                0.127725
# 1         0.191466            0.134432                0.172394
# 2         0.159237            0.117933                0.115415
# 3         0.153974            0.125554                0.123964
# 4         0.169862            0.143023                0.133794
#
#    household_size_error  vehicles_error  mean_error
# 0              0.107163        0.137199    0.133766
# 1              0.119281        0.181832    0.159881
# 2              0.094489        0.122057    0.121826
# 3              0.101951        0.149347    0.130958
# 4              0.112537        0.149698    0.141783

# %%
experiment_results = experiment_results[experiment_results['num_sample'] <= 20000]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot accuracy on the primary y-axis
sns.lineplot(data=experiment_results, x='num_sample',
             y='loss', ax=ax1, color='b', label='Loss')
# sns.lineplot(data=experiment_results, x='num_sample',
#              y='brier_score', ax=ax1, color='#880E4F', label='Average Brier Score')

ax1.set_title('Loss and Error')
ax1.set_xlabel('Number of Samples')
ax1.set_ylabel('Categorical Cross-Entropy Loss')
ax1.legend(loc='upper left')

# Create a second y-axis for the errors
ax2 = ax1.twinx()
sns.lineplot(data=experiment_results, x='num_sample', y='age_group_error',
             ax=ax2, color='r', linestyle='--', label='Age Error')
sns.lineplot(data=experiment_results, x='num_sample', y='income_group_error',
             ax=ax2, color='g', linestyle='-.', label='Income Error')
sns.lineplot(data=experiment_results, x='num_sample', y='mean_error',
             ax=ax2, color='y', linestyle='-.', label='Mean Error')
ax2.set_ylabel('Mean Absolute Percentage Error')
ax2.legend(loc='upper right')

# Optional: Set xticks if needed
# ax1.set_xticks(experiment_results['num_sample'])

plt.show()
